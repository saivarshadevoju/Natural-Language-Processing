# %% [markdown]
# ## Porter Stemmer

# %%
## Classification Problem
## Comments of product is a positive review or negative review
## reviews --> eating, eat, eaten [going, gone, goes]-->go

words = ["eating","eats","eaten","writing","writes","programming","programs","history","finally","finalized"]

# %%
from nltk.stem import PorterStemmer
stemming = PorterStemmer()

# %%
for word in words:
    print(word + " ---> " + stemming.stem(word))
# Out:
# eating ---> eat
# eats ---> eat
# eaten ---> eaten
# writing ---> write
# writes ---> write
# programming ---> program
# programs ---> program
# history ---> histori
# finally ---> final
# finalized ---> final

# %%
#Major Disadvantage of Stemming

stemming.stem("congragulations")
# Out:
# 'congragul'

# %%
stemming.stem("sitting")
# Out:
# 'sit'

# %% [markdown]
# ## RegexpStemmer Class

# %%
from nltk.stem import RegexpStemmer
reg_stemmer = RegexpStemmer('ing$|^un', min=4)

# %%
reg_stemmer.stem('eating')
# Out:
# 'eat'

# %%
reg_stemmer.stem('ungrateful')
# Out:
# 'grateful'

# %% [markdown]
# ## Snowball Stemmer

# %%
from nltk.stem import SnowballStemmer
snow_stemmer = SnowballStemmer('english')

# %%
for word in words:
    print(word + " ---> " + snow_stemmer.stem(word) )
# Out:
# eating ---> eat
# eats ---> eat
# eaten ---> eaten
# writing ---> write
# writes ---> write
# programming ---> program
# programs ---> program
# history ---> histori
# finally ---> final
# finalized ---> final

# %%
stemming.stem("fairly"), snow_stemmer.stem("fairly")
# Out:
# ('fairli', 'fair')
